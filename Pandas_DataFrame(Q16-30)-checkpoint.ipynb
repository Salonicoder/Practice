# %% [markdown]
# # Pandas DataFrame

# %%
import pandas as pd
import numpy as np

# %%
#Q16
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data , index=labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df = df.sort_values(by = ['name', 'score'], ascending=[False, True])
df
# Out:
#         name  score  attempts qualify
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# b       Dima    9.0         3      no
# a  Anastasia   12.5         1     yes

# %%
#Q17
df['qualify'] = df['qualify'].map({'yes': True, 'no': False})
df
# Out:
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d      James    NaN         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %%
#Q18
df['name'] = df['name'].replace('James', 'Suresh')
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d     Suresh    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#Q19
df.pop('attempts')
df
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# d     Suresh    NaN      no
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# h      Laura    NaN      no
# i      Kevin    8.0      no
# j      Jonas   19.0     yes

# %%
#Q20
sub = ['Maths', 'Science', 'English', 'Hindi', 'Social Science','Maths', 'Science', 'English', 'Hindi', 'Social Science' ]
df['subject'] = sub
df
# Out:
#         name  score  attempts qualify         subject
# a  Anastasia   12.5         1     yes           Maths
# b       Dima    9.0         3      no         Science
# c  Katherine   16.5         2     yes         English
# d      James    NaN         3      no           Hindi
# e      Emily    9.0         2      no  Social Science
# f    Michael   20.0         3     yes           Maths
# g    Matthew   14.5         1     yes         Science
# h      Laura    NaN         1      no         English
# i      Kevin    8.0         2      no           Hindi
# j      Jonas   19.0         1     yes  Social Science

# %%
#Q21
exam_data = [{'name':'Anastasia', 'score':12.5}, {'name':'Dima','score':9}, {'name':'Katherine','score':16.5}]
df = pd.DataFrame(exam_data)

for index, row in df.iterrows():
    print(row['name'], row['score'])
# Out:
# Anastasia 12.5
# Dima 9.0
# Katherine 16.5

# %%
#Q22
list(df.columns.values)
# Out:
# ['name', 'score', 'attempts', 'qualify']

# %%
#Q23
ori = {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}
df = pd.DataFrame(data=ori)
print("Original DataFrame")
print(df)

df.columns = ['Column1', 'Column2', 'Column3']
df = df.rename(columns={'col1': 'Column1', 'col2': 'Column2', 'col3': 'Column3'})
print("New DataFrame after renaming columns:")
print(df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# New DataFrame after renaming columns:
#    Column1  Column2  Column3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %%
#Q24
df.loc[df['Column1'] == 2]
# Out:
#    Column1  Column2  Column3
# 1        2        5        8

# %%
#Q25
ori = {'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9]}
df = pd.DataFrame(data=ori)
print("Original DataFrame")
print(df)
print('After altering col1 and col3')
df = df[['col3', 'col2', 'col1']]
print(df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# After altering col1 and col3
#    col3  col2  col1
# 0     7     4     1
# 1     8     5     2
# 2     9     6     3

# %%
#Q26
ori = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(data=ori)
print("Original DataFrame")
print(df)
print('After add one row:')
df2 = {'col1': 10, 'col2': 11, 'col3': 12}
df = df.append(df2, ignore_index=True)
print(df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# After add one row:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# 5    10    11    12

# %%
#Q27
ori = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(data=ori)
print("Original DataFrame")
print(df)
print('Data from new_file.csv file:')
df.to_csv('new_file.csv', sep='\t', index=False)
new_df = pd.read_csv('new_file.csv')
print(new_df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# Data from new_file.csv file:
#   col1\tcol2\tcol3
# 0          1\t4\t7
# 1          4\t5\t8
# 2          3\t6\t9
# 3          4\t7\t0
# 4          5\t8\t1

# %%
#28
df1 = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'city': ['California', 'Los Angeles', 'California', 'California', 'California', 'Los Angeles', 'Los Angeles', 'Georgia', 'Georgia', 'Los Angeles']})
g1 = df1.groupby(["city"]).size().reset_index(name='Number of people')
print(g1)
# Out:
#           city  Number of people
# 0   California                 4
# 1      Georgia                 2
# 2  Los Angeles                 4

# %%
#Q29
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(data=d)
print("Original DataFrame")
print(df)
df = df[df.col2 != 5]
print("New DataFrame")
print(df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# New DataFrame
#    col1  col2  col3
# 0     1     4     7
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
#Q30
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(data=d)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
print("Original DataFrame")
print(df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
